# %% [markdown]
# # Aula 4.1 - Introdução a Pandas, pt2
#
# Já discutimos de forma mais básica quais são as estruturas de dados principais do Pandas: DataFrames e Series. Além disso, vimos também como ler um arquivo csv, ou como criar um dataframe a partir de dados no próprio Python.
#
# Hoje, vamos aprender a explorar nossas tabelas em pandas. Como ver quantas entradas eu tenho? Quais os tipos de entradas? Como eu deixo meus dados em um formato melhor para minhas análises?

# %% [markdown]
# ---

# %% [markdown]
# Vamos usar os dados da última aula, e tentar aproveitar o Pandas para extrair algumas informações. Enquanto mostramos as funcionalidades por aqui, vamos tentar ir reproduzindo o passo a passo com dados do IBGE!
#
# O objetivo dessa primeira parte é aprendermos algumas funcionalidades básicas para começarmos a olhar os nossos dados. É sempre importante sabermos qual tipo de dados nós temos, qual a cara deles, se tem algum erro, quantas linhas temos, etc...
#
# Isso nos ajuda muito a nos preparar para de fato começar a fazer análises de dados.

# %% [markdown]
# ## Lendo o arquivo

# %%
# Começamos sempre importando nossas bibliotecas.
import numpy as np
import pandas as pd

# %%
# A função "read_table" é equivalente à "read_csv", só muda que ela é mais geral.
# Tente ler abaixo os dados de população para um dataframe, usando pd.read_table
df = pd.read_table('dados/dados_parciais.txt',
                   sep=';', decimal=',')

# DICA: Procura o parâmetro "thousands"

# %%
df
# Out:
#           regiao        uf  superficie  pop_urbana  pop_rural       total
# 0          Norte        RO      238513    762864.0   468143.0   1231007.0
# 1          Norte        AC      153150    315401.0   168322.0    483726.0
# 2          Norte        AM     1577820   1766166.0   623113.0   2389279.0
# 3          Norte        RR      225116    174277.0    72854.0    247131.0
# 4          Norte        PA     1253165   2949017.0  2561832.0   5510849.0
# 5          Norte        AP      143454    330590.0    48869.0    379459.0
# 6          Norte        TO      278421    741009.0   307633.0   1048642.0
# 7       Nordeste        MA      333366   2711557.0  2511008.0   5222565.0
# 8       Nordeste        PI      252379   1556115.0  1117061.0   2673176.0
# 9       Nordeste  Litígio*        2977         NaN        NaN         NaN
# 10      Nordeste        CE      146348   4713311.0  2096483.0   6809794.0
# 11      Nordeste        RN       53307   1843486.0   715174.0   2558660.0
# 12      Nordeste        PB       56585   2261986.0  1043630.0   3305616.0
# 13      Nordeste      PE**       98938   5476915.0  1922216.0   7399131.0
# 14      Nordeste        AL       27933   1661914.0   971425.0   2633339.0
# 15      Nordeste        SE       22050   1140569.0   483606.0   1624175.0
# 16      Nordeste        BA      567295   7826843.0  4714902.0  12541745.0
# 17       Sudeste        MG      588384  13074245.0  3598852.0  16673097.0
# 18       Sudeste        ES       46184   2176006.0   626701.0   2802707.0
# 19       Sudeste        RJ       43910  12806488.0   599891.0  13406379.0
# 20       Sudeste        SP      248809  31769219.0  2351667.0  34120886.0
# 21           Sul        PR      199709   7011990.0  1991814.0   9003804.0
# 22           Sul        SC       95443   3565130.0  1310114.0   4875244.0
# 23           Sul        RS      282062   7581230.0  2056452.0   9637682.0
# 24  Centro-Oeste        MS      358159   1604318.0   323516.0   1927834.0
# 25  Centro-Oeste        MT      906807   1695548.0   540284.0   2235832.0
# 26  Centro-Oeste        GO     3412895   3873722.0   642146.0   4515868.0
# 27  Centro-Oeste        DF        5822   1692248.0   129698.0   1821946.0
# 28           NaN  Ilhas***          10         NaN        NaN         NaN

# %%
# Antes de começarmos a processar nossos dados, queremos entender algumas coisas básicas sobre eles.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   regiao      28 non-null     object
#  1   uf          29 non-null     object
#  2   superficie  29 non-null     int64
#  3   pop_urbana  27 non-null     float64
#  4   pop_rural   27 non-null     float64
#  5   total       27 non-null     float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 1.5+ KB

# %%
df.head(3)
# Out:
#   regiao  uf  superficie  pop_urbana  pop_rural      total
# 0  Norte  RO      238513    762864.0   468143.0  1231007.0
# 1  Norte  AC      153150    315401.0   168322.0   483726.0
# 2  Norte  AM     1577820   1766166.0   623113.0  2389279.0

# %%
df.shape
# Out:
# (29, 6)

# %%
df.count()
# Out:
# regiao        28
# uf            29
# superficie    29
# pop_urbana    27
# pop_rural     27
# total         27
# dtype: int64

# %%
cols = df.columns

# %%
print(type(cols))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
cols.to_numpy()
# Out:
# array(['regiao', 'uf', 'superficie', 'pop_urbana', 'pop_rural', 'total'],
#       dtype=object)

# %%
cols.to_series()
# Out:
# regiao            regiao
# uf                    uf
# superficie    superficie
# pop_urbana    pop_urbana
# pop_rural      pop_rural
# total              total
# dtype: object

# %%
cols.to_list()
# Out:
# ['regiao', 'uf', 'superficie', 'pop_urbana', 'pop_rural', 'total']

# %%
cols.values
# Out:
# array(['regiao', 'uf', 'superficie', 'pop_urbana', 'pop_rural', 'total'],
#       dtype=object)

# %%
list(cols)
# Out:
# ['regiao', 'uf', 'superficie', 'pop_urbana', 'pop_rural', 'total']

# %%
df.columns = ['regiao', 'estado', 'area', 'pop_urb', 'pop_rur', 'total']

# %%
df2 = df.columns.copy()

# %%
print(type(df.columns))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %%
df.head(10)
# Out:
#      regiao    estado     area    pop_urb    pop_rur      total
# 0     Norte        RO   238513   762864.0   468143.0  1231007.0
# 1     Norte        AC   153150   315401.0   168322.0   483726.0
# 2     Norte        AM  1577820  1766166.0   623113.0  2389279.0
# 3     Norte        RR   225116   174277.0    72854.0   247131.0
# 4     Norte        PA  1253165  2949017.0  2561832.0  5510849.0
# 5     Norte        AP   143454   330590.0    48869.0   379459.0
# 6     Norte        TO   278421   741009.0   307633.0  1048642.0
# 7  Nordeste        MA   333366  2711557.0  2511008.0  5222565.0
# 8  Nordeste        PI   252379  1556115.0  1117061.0  2673176.0
# 9  Nordeste  Litígio*     2977        NaN        NaN        NaN

# %%
# e se eu só quisesse renomear 1 coluna?
df2 = df.rename(columns = {'reg':'pudim'}).copy()

# %%
df.head(2)
# Out:
#      reg estado    area   pop_urb   pop_rur      total
# 0  Norte     RO  238513  762864.0  468143.0  1231007.0
# 1  Norte     AC  153150  315401.0  168322.0   483726.0

# %%
df2.head(2)
# Out:
#    pudim estado    area   pop_urb   pop_rur      total
# 0  Norte     RO  238513  762864.0  468143.0  1231007.0
# 1  Norte     AC  153150  315401.0  168322.0   483726.0

# %%
import numpy as np

palavra = "Pudim"
lista = [1, 2, 3]
arr = np.array([1, 2, 3])

# %%
p2 = palavra
p2[1] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-a4c6689f9498> in <module>
#       1 p2 = palavra
# ----> 2 p2[1] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %%
p2 = 'bolo'

# %%
print(p2)
# Out:
# bolo

# %%
print(palavra)
# Out:
# Pudim

# %%
p2[1]
# Out:
# 'u'

# %%
nova_lista = lista
nova_lista[1] = 10

# %%
print(nova_lista)
# Out:
# [1, 10, 3]

# %%
print(lista)
# Out:
# [1, 10, 3]

# %%
from copy import copy

# %%
nova_lista2 = copy(nova_lista)

# %%
nova_lista2[2] = 30

# %%
print(nova_lista2)
# Out:
# [1, 10, 30]

# %%
print(nova_lista)
# Out:
# [1, 10, 3]

# %%
new_arr = arr
new_arr[1] = 10
print(new_arr)
print(arr)
# Out:
# [ 1 10  3]
# [ 1 10  3]

# %%
new_arr2 = new_arr.copy()
new_arr2[2] = 30
print(new_arr)
print(new_arr2)
# Out:
# [ 1 10  3]
# [ 1 10 30]

# %%
# Esse .copy é chato. Dá pra fazer direto, alterar o dataframe nele próprio?
# Consigo, embora não seja bom ficar fazendo isso o tempo todo.
df.rename(columns = {'estado':'uf'}, inplace=True)

# %%
df.head(2)
# Out:
#      reg  uf    area   pop_urb   pop_rur      total
# 0  Norte  RO  238513  762864.0  468143.0  1231007.0
# 1  Norte  AC  153150  315401.0  168322.0   483726.0

# %%
# Também podemos jogar colunas fora.
df.drop(columns=['total'], inplace=True)

# %%
df.columns
# Out:
# Index(['reg', 'uf', 'area', 'pop_urb', 'pop_rur'], dtype='object')

# %% [markdown]
# ## Manipulando meu dataframe

# %%
# Meu dataframe consiste em:
# Um índice
# Colunas (que são series)

# Para pegar o meu índice.
df.index
# Out:
# RangeIndex(start=0, stop=29, step=1)

# %%
# A primeira coisa que queremos aprender é como acessar os elementos do meu dataframe.
# Existem diversas formas de fazer isso.

# Vamos tentar acessar elementos da quinta linha do meu dataframe.
quinta_linha = df.iloc[5]

# i: índice
# loc: localização

# %%
df.head(6)
# Out:
#   regiao  uf  superficie  pop_urbana  pop_rural      total
# 0  Norte  RO      238513    762864.0   468143.0  1231007.0
# 1  Norte  AC      153150    315401.0   168322.0   483726.0
# 2  Norte  AM     1577820   1766166.0   623113.0  2389279.0
# 3  Norte  RR      225116    174277.0    72854.0   247131.0
# 4  Norte  PA     1253165   2949017.0  2561832.0  5510849.0
# 5  Norte  AP      143454    330590.0    48869.0   379459.0

# %%
quinta_linha
# Out:
# regiao         Norte
# uf                AP
# superficie    143454
# pop_urbana    330590
# pop_rural      48869
# total         379459
# Name: 5, dtype: object

# %%
# Essa quinta linha vai ser um Pandas Series!
print(type(quinta_linha))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Podemos então pegar um elemento da quinta linha pela posição, ou pelo nome do index.
quinta_linha.iloc[1]
# Out:
# 'AP'

# %%
quinta_linha.loc['uf']

# loc: localização
# Out:
# 'AP'

# %%
quinta_linha.index
# Out:
# Index(['regiao', 'uf', 'superficie', 'pop_urbana', 'pop_rural', 'total'], dtype='object')

# %%
quinta_linha['uf']
# Out:
# 'AP'

# %%
# O mesmo pode ser feito diretamente com o DataFrame
df.loc[5, 'uf']
# Out:
# 'AP'

# %%
df.iloc[5, 1]
# Out:
# 'AP'

# %%
df.iat[5, 1]

# i: índice
# at: estou
# Out:
# 'AP'

# %%
df2 = df.copy()

# %%
df2.iat[5, 1] = 'PUDIM'

# %%
df2.head(6)
# Out:
#   regiao     uf  superficie  pop_urbana  pop_rural      total
# 0  Norte     RO      238513    762864.0   468143.0  1231007.0
# 1  Norte     AC      153150    315401.0   168322.0   483726.0
# 2  Norte     AM     1577820   1766166.0   623113.0  2389279.0
# 3  Norte     RR      225116    174277.0    72854.0   247131.0
# 4  Norte     PA     1253165   2949017.0  2561832.0  5510849.0
# 5  Norte  PUDIM      143454    330590.0    48869.0   379459.0

# %%
df2.iat[5, 'uf']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-a24a68b3f322> in <module>
# ----> 1 df2.iat[5, 'uf']
#
# ~/miniconda3/envs/data_science/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2176                 raise ValueError("Invalid call for scalar access (getting)!")
#    2177
# -> 2178         key = self._convert_key(key)
#    2179         return self.obj._get_value(*key, takeable=self._takeable)
#    2180
#
# ~/miniconda3/envs/data_science/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_key(self, key, is_setter)
#    2235         for a, i in zip(self.obj.axes, key):
#    2236             if not is_integer(i):
# -> 2237                 raise ValueError("iAt based indexing can only have integer indexers")
#    2238         return key
#    2239
#
# ValueError: iAt based indexing can only have integer indexers

# %%
df2.at[5, 'uf'] = "AP"

# %%
# Também podemos pegar subconjuntos de linhas através de slicing
df.loc[:5, 'uf']

# Ou através de uma máscara booleana
df.loc[df['regiao'] == 'Centro-Oeste']
# Out:
# 0    RO
# 1    AC
# 2    AM
# 3    RR
# 4    PA
# 5    AP
# Name: uf, dtype: object

# %%
print(type(df['regiao']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df['regiao'] == 'Centro-Oeste'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25     True
# 26     True
# 27     True
# 28    False
# Name: regiao, dtype: bool

# %%
# Ou através de uma máscara booleana
df.loc[df['regiao'] == 'Centro-Oeste']
# Out:
#           regiao  uf  superficie  pop_urbana  pop_rural      total
# 24  Centro-Oeste  MS      358159   1604318.0   323516.0  1927834.0
# 25  Centro-Oeste  MT      906807   1695548.0   540284.0  2235832.0
# 26  Centro-Oeste  GO     3412895   3873722.0   642146.0  4515868.0
# 27  Centro-Oeste  DF        5822   1692248.0   129698.0  1821946.0

# %%
# Pode ser também que queiramos trabalhar com colunas.
regioes = df['regiao']

# %%
print(type(regioes))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Se o nome da coluna não tiver espaço, também podemos pegar os seus valores usando ponto.
df.regiao
# Out:
# 0            Norte
# 1            Norte
# 2            Norte
# 3            Norte
# 4            Norte
# 5            Norte
# 6            Norte
# 7         Nordeste
# 8         Nordeste
# 9         Nordeste
# 10        Nordeste
# 11        Nordeste
# 12        Nordeste
# 13        Nordeste
# 14        Nordeste
# 15        Nordeste
# 16        Nordeste
# 17         Sudeste
# 18         Sudeste
# 19         Sudeste
# 20         Sudeste
# 21             Sul
# 22             Sul
# 23             Sul
# 24    Centro-Oeste
# 25    Centro-Oeste
# 26    Centro-Oeste
# 27    Centro-Oeste
# 28             NaN
# Name: regiao, dtype: object

# %%
# Pegar subconjuntos de colunas 
df[['regiao', 'uf']]
# Out:
#           regiao        uf
# 0          Norte        RO
# 1          Norte        AC
# 2          Norte        AM
# 3          Norte        RR
# 4          Norte        PA
# 5          Norte        AP
# 6          Norte        TO
# 7       Nordeste        MA
# 8       Nordeste        PI
# 9       Nordeste  Litígio*
# 10      Nordeste        CE
# 11      Nordeste        RN
# 12      Nordeste        PB
# 13      Nordeste      PE**
# 14      Nordeste        AL
# 15      Nordeste        SE
# 16      Nordeste        BA
# 17       Sudeste        MG
# 18       Sudeste        ES
# 19       Sudeste        RJ
# 20       Sudeste        SP
# 21           Sul        PR
# 22           Sul        SC
# 23           Sul        RS
# 24  Centro-Oeste        MS
# 25  Centro-Oeste        MT
# 26  Centro-Oeste        GO
# 27  Centro-Oeste        DF
# 28           NaN  Ilhas***

# %%
df[df['regiao'] == 'Centro-Oeste']['total'] = [1, 2, 3, 4]
# Out:
# /home/alexandre/miniconda3/envs/data_science/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df[df['regiao'] == 'Centro-Oeste']
# Out:
#           regiao  uf  superficie  pop_urbana  pop_rural      total
# 24  Centro-Oeste  MS      358159   1604318.0   323516.0  1927834.0
# 25  Centro-Oeste  MT      906807   1695548.0   540284.0  2235832.0
# 26  Centro-Oeste  GO     3412895   3873722.0   642146.0  4515868.0
# 27  Centro-Oeste  DF        5822   1692248.0   129698.0  1821946.0

# %%
df.loc[df['regiao'] == 'Centro-Oeste', 'total'] = [1, 2, 3, 4]

# %%
df.loc[df['regiao'] == 'Centro-Oeste']
# Out:
#           regiao  uf  superficie  pop_urbana  pop_rural  total
# 24  Centro-Oeste  MS      358159   1604318.0   323516.0    1.0
# 25  Centro-Oeste  MT      906807   1695548.0   540284.0    2.0
# 26  Centro-Oeste  GO     3412895   3873722.0   642146.0    3.0
# 27  Centro-Oeste  DF        5822   1692248.0   129698.0    4.0

# %%
# A função "read_table" é equivalente à "read_csv", só muda que ela é mais geral.
# Tente ler abaixo os dados de população para um dataframe, usando pd.read_table
df = pd.read_table('dados/dados_parciais.txt',
                   sep=';', decimal=',')

# DICA: Procura o parâmetro "thousands"

# %%
df.head(5)
# Out:
#   regiao  uf  superficie  pop_urbana  pop_rural      total
# 0  Norte  RO      238513    762864.0   468143.0  1231007.0
# 1  Norte  AC      153150    315401.0   168322.0   483726.0
# 2  Norte  AM     1577820   1766166.0   623113.0  2389279.0
# 3  Norte  RR      225116    174277.0    72854.0   247131.0
# 4  Norte  PA     1253165   2949017.0  2561832.0  5510849.0

# %%
area_sup = df['superficie']

# %%
total = df['total']

# %%
total / area_sup
# Out:
# 0       5.161174
# 1       3.158511
# 2       1.514291
# 3       1.097794
# 4       4.397545
# 5       2.645162
# 6       3.766390
# 7      15.666160
# 8      10.591911
# 9            NaN
# 10     46.531514
# 11     47.998574
# 12     58.418591
# 13     74.785532
# 14     94.273404
# 15     73.658730
# 16     22.107977
# 17     28.337101
# 18     60.685670
# 19    305.314940
# 20    137.136864
# 21     45.084618
# 22     51.080163
# 23     34.168665
# 24      5.382621
# 25      2.465610
# 26      1.323178
# 27    312.941601
# 28           NaN
# dtype: float64

# %%
df['densidade'] = total / area_sup

# %%
df.head(7)
# Out:
#   regiao  uf  superficie  pop_urbana  pop_rural      total  densidade
# 0  Norte  RO      238513    762864.0   468143.0  1231007.0   5.161174
# 1  Norte  AC      153150    315401.0   168322.0   483726.0   3.158511
# 2  Norte  AM     1577820   1766166.0   623113.0  2389279.0   1.514291
# 3  Norte  RR      225116    174277.0    72854.0   247131.0   1.097794
# 4  Norte  PA     1253165   2949017.0  2561832.0  5510849.0   4.397545
# 5  Norte  AP      143454    330590.0    48869.0   379459.0   2.645162
# 6  Norte  TO      278421    741009.0   307633.0  1048642.0   3.766390

# %%
# A função "read_table" é equivalente à "read_csv", só muda que ela é mais geral.
# Tente ler abaixo os dados de população para um dataframe, usando pd.read_table
df = pd.read_table('dados/dados_parciais.txt',
                   sep=';', decimal=',')

# DICA: Procura o parâmetro "thousands"

# %%
df['densidade'] = df['total'] / df['superficie']

# %%
df.head(3)
# Out:
#   regiao  uf  superficie  pop_urbana  pop_rural      total  densidade
# 0  Norte  RO      238513    762864.0   468143.0  1231007.0   5.161174
# 1  Norte  AC      153150    315401.0   168322.0   483726.0   3.158511
# 2  Norte  AM     1577820   1766166.0   623113.0  2389279.0   1.514291

# %%
df.loc[:, 'perc_rural'] = df['pop_rural'] / df['total']

# %%
df.head(3)
# Out:
#   regiao  uf  superficie  pop_urbana  pop_rural      total  densidade  \
# 0  Norte  RO      238513    762864.0   468143.0  1231007.0   5.161174
# 1  Norte  AC      153150    315401.0   168322.0   483726.0   3.158511
# 2  Norte  AM     1577820   1766166.0   623113.0  2389279.0   1.514291
#
#    perc_rural
# 0    0.380293
# 1    0.347970
# 2    0.260795

# %%
df['nao_sei_porque'] = df['densidade'] * df['perc_rural']

# %%
df.head(3)
# Out:
#   regiao  uf  superficie  pop_urbana  pop_rural      total  densidade  \
# 0  Norte  RO      238513    762864.0   468143.0  1231007.0   5.161174
# 1  Norte  AC      153150    315401.0   168322.0   483726.0   3.158511
# 2  Norte  AM     1577820   1766166.0   623113.0  2389279.0   1.514291
#
#    perc_rural  nao_sei_porque
# 0    0.380293        1.962757
# 1    0.347970        1.099066
# 2    0.260795        0.394920

# %%
# Ok, até agora, que diferença fez eu ter Pandas Series?
df.regiao.value_counts() # Eu posso pegar quantos estados tenho em cada região.

# %%
df.regiao
# Out:
# 0            Norte
# 1            Norte
# 2            Norte
# 3            Norte
# 4            Norte
# 5            Norte
# 6            Norte
# 7         Nordeste
# 8         Nordeste
# 9         Nordeste
# 10        Nordeste
# 11        Nordeste
# 12        Nordeste
# 13        Nordeste
# 14        Nordeste
# 15        Nordeste
# 16        Nordeste
# 17         Sudeste
# 18         Sudeste
# 19         Sudeste
# 20         Sudeste
# 21             Sul
# 22             Sul
# 23             Sul
# 24    Centro-Oeste
# 25    Centro-Oeste
# 26    Centro-Oeste
# 27    Centro-Oeste
# 28             NaN
# Name: regiao, dtype: object

# %%
df.regiao.value_counts()
# Out:
# Nordeste        10
# Norte            7
# Sudeste          4
# Centro-Oeste     4
# Sul              3
# Name: regiao, dtype: int64

# %%
# Quantos estados têm população acima de 1 milhão de habitantes?
series = df.total > 1000000

# %%
series
# Out:
# 0      True
# 1     False
# 2      True
# 3     False
# 4      True
# 5     False
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28    False
# Name: total, dtype: bool

# %%
series.head(10)
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7     True
# 8     True
# 9    False
# Name: total, dtype: bool

# %%
series.value_counts()
# Out:
# True     24
# False     5
# Name: total, dtype: int64

# %%
df.loc[~series]
# Out:
#       regiao        uf  superficie  pop_urbana  pop_rural     total  \
# 1      Norte        AC      153150    315401.0   168322.0  483726.0
# 3      Norte        RR      225116    174277.0    72854.0  247131.0
# 5      Norte        AP      143454    330590.0    48869.0  379459.0
# 9   Nordeste  Litígio*        2977         NaN        NaN       NaN
# 28       NaN  Ilhas***          10         NaN        NaN       NaN
#
#     densidade  perc_rural  nao_sei_porque
# 1    3.158511    0.347970        1.099066
# 3    1.097794    0.294799        0.323629
# 5    2.645162    0.128786        0.340660
# 9         NaN         NaN             NaN
# 28        NaN         NaN             NaN

# %%
mask_regiao = df['regiao'] == 'Norte'
mask_pop = df['total'] > 1000000

# %%
# Negando o valor booleano
df.loc[~mask_regiao] #aqui a gente pega quem não é do norte (Lannisters)
# Out:
#           regiao        uf  superficie  pop_urbana  pop_rural       total  \
# 7       Nordeste        MA      333366   2711557.0  2511008.0   5222565.0
# 8       Nordeste        PI      252379   1556115.0  1117061.0   2673176.0
# 9       Nordeste  Litígio*        2977         NaN        NaN         NaN
# 10      Nordeste        CE      146348   4713311.0  2096483.0   6809794.0
# 11      Nordeste        RN       53307   1843486.0   715174.0   2558660.0
# 12      Nordeste        PB       56585   2261986.0  1043630.0   3305616.0
# 13      Nordeste      PE**       98938   5476915.0  1922216.0   7399131.0
# 14      Nordeste        AL       27933   1661914.0   971425.0   2633339.0
# 15      Nordeste        SE       22050   1140569.0   483606.0   1624175.0
# 16      Nordeste        BA      567295   7826843.0  4714902.0  12541745.0
# 17       Sudeste        MG      588384  13074245.0  3598852.0  16673097.0
# 18       Sudeste        ES       46184   2176006.0   626701.0   2802707.0
# 19       Sudeste        RJ       43910  12806488.0   599891.0  13406379.0
# 20       Sudeste        SP      248809  31769219.0  2351667.0  34120886.0
# 21           Sul        PR      199709   7011990.0  1991814.0   9003804.0
# 22           Sul        SC       95443   3565130.0  1310114.0   4875244.0
# 23           Sul        RS      282062   7581230.0  2056452.0   9637682.0
# 24  Centro-Oeste        MS      358159   1604318.0   323516.0   1927834.0
# 25  Centro-Oeste        MT      906807   1695548.0   540284.0   2235832.0
# 26  Centro-Oeste        GO     3412895   3873722.0   642146.0   4515868.0
# 27  Centro-Oeste        DF        5822   1692248.0   129698.0   1821946.0
# 28           NaN  Ilhas***          10         NaN        NaN         NaN
#
#      densidade  perc_rural  nao_sei_porque
# 7    15.666160    0.480800        7.532286
# 8    10.591911    0.417878        4.426125
# 9          NaN         NaN             NaN
# 10   46.531514    0.307863       14.325327
# 11   47.998574    0.279511       13.416137
# 12   58.418591    0.315714       18.443580
# 13   74.785532    0.259789       19.428491
# 14   94.273404    0.368895       34.776966
# 15   73.658730    0.297755       21.932245
# 16   22.107977    0.375937        8.311200
# 17   28.337101    0.215848        6.116502
# 18   60.685670    0.223606       13.569656
# 19  305.314940    0.044747       13.661831
# 20  137.136864    0.068922        9.451696
# 21   45.084618    0.221219        9.973582
# 22   51.080163    0.268728       13.726664
# 23   34.168665    0.213376        7.290780
# 24    5.382621    0.167813        0.903275
# 25    2.465610    0.241648        0.595809
# 26    1.323178    0.142198        0.188153
# 27  312.941601    0.071187       22.277224
# 28         NaN         NaN             NaN

# %%
# fazendo o OU do valor booleano
df.loc[mask_regiao | mask_pop]
# Out:
#           regiao    uf  superficie  pop_urbana  pop_rural       total  \
# 0          Norte    RO      238513    762864.0   468143.0   1231007.0
# 1          Norte    AC      153150    315401.0   168322.0    483726.0
# 2          Norte    AM     1577820   1766166.0   623113.0   2389279.0
# 3          Norte    RR      225116    174277.0    72854.0    247131.0
# 4          Norte    PA     1253165   2949017.0  2561832.0   5510849.0
# 5          Norte    AP      143454    330590.0    48869.0    379459.0
# 6          Norte    TO      278421    741009.0   307633.0   1048642.0
# 7       Nordeste    MA      333366   2711557.0  2511008.0   5222565.0
# 8       Nordeste    PI      252379   1556115.0  1117061.0   2673176.0
# 10      Nordeste    CE      146348   4713311.0  2096483.0   6809794.0
# 11      Nordeste    RN       53307   1843486.0   715174.0   2558660.0
# 12      Nordeste    PB       56585   2261986.0  1043630.0   3305616.0
# 13      Nordeste  PE**       98938   5476915.0  1922216.0   7399131.0
# 14      Nordeste    AL       27933   1661914.0   971425.0   2633339.0
# 15      Nordeste    SE       22050   1140569.0   483606.0   1624175.0
# 16      Nordeste    BA      567295   7826843.0  4714902.0  12541745.0
# 17       Sudeste    MG      588384  13074245.0  3598852.0  16673097.0
# 18       Sudeste    ES       46184   2176006.0   626701.0   2802707.0
# 19       Sudeste    RJ       43910  12806488.0   599891.0  13406379.0
# 20       Sudeste    SP      248809  31769219.0  2351667.0  34120886.0
# 21           Sul    PR      199709   7011990.0  1991814.0   9003804.0
# 22           Sul    SC       95443   3565130.0  1310114.0   4875244.0
# 23           Sul    RS      282062   7581230.0  2056452.0   9637682.0
# 24  Centro-Oeste    MS      358159   1604318.0   323516.0   1927834.0
# 25  Centro-Oeste    MT      906807   1695548.0   540284.0   2235832.0
# 26  Centro-Oeste    GO     3412895   3873722.0   642146.0   4515868.0
# 27  Centro-Oeste    DF        5822   1692248.0   129698.0   1821946.0
#
#      densidade  perc_rural  nao_sei_porque
# 0     5.161174    0.380293        1.962757
# 1     3.158511    0.347970        1.099066
# 2     1.514291    0.260795        0.394920
# 3     1.097794    0.294799        0.323629
# 4     4.397545    0.464871        2.044289
# 5     2.645162    0.128786        0.340660
# 6     3.766390    0.293363        1.104920
# 7    15.666160    0.480800        7.532286
# 8    10.591911    0.417878        4.426125
# 10   46.531514    0.307863       14.325327
# 11   47.998574    0.279511       13.416137
# 12   58.418591    0.315714       18.443580
# 13   74.785532    0.259789       19.428491
# 14   94.273404    0.368895       34.776966
# 15   73.658730    0.297755       21.932245
# 16   22.107977    0.375937        8.311200
# 17   28.337101    0.215848        6.116502
# 18   60.685670    0.223606       13.569656
# 19  305.314940    0.044747       13.661831
# 20  137.136864    0.068922        9.451696
# 21   45.084618    0.221219        9.973582
# 22   51.080163    0.268728       13.726664
# 23   34.168665    0.213376        7.290780
# 24    5.382621    0.167813        0.903275
# 25    2.465610    0.241648        0.595809
# 26    1.323178    0.142198        0.188153
# 27  312.941601    0.071187       22.277224

# %%
# fazendo o E do valor booleano
df.loc[mask_regiao & mask_pop]
# Out:
#   regiao  uf  superficie  pop_urbana  pop_rural      total  densidade  \
# 0  Norte  RO      238513    762864.0   468143.0  1231007.0   5.161174
# 2  Norte  AM     1577820   1766166.0   623113.0  2389279.0   1.514291
# 4  Norte  PA     1253165   2949017.0  2561832.0  5510849.0   4.397545
# 6  Norte  TO      278421    741009.0   307633.0  1048642.0   3.766390
#
#    perc_rural  nao_sei_porque
# 0    0.380293        1.962757
# 2    0.260795        0.394920
# 4    0.464871        2.044289
# 6    0.293363        1.104920

# %%
# Também podemos tentar ver quais são os elementos únicos de uma pandas series.
regioes = df.regiao

# %%
regioes.unique()
# Out:
# array(['Norte', 'Nordeste', 'Sudeste', 'Sul', 'Centro-Oeste', nan],
#       dtype=object)

# %%
regioes.nunique()
# Out:
# 5

# %% [markdown]
# Podemos também fazer alterações no dataframe, de forma que nos ajude a ter mais informações.

# %%
# Eu posso reorganizar o meu dataframe de acordo com qualquer coluna.
sorted_values = df.sort_values(by='total', ascending=False).copy()

# %%
sorted_values.head(10)
# Out:
#       regiao    uf  superficie  pop_urbana  pop_rural       total   densidade  \
# 20   Sudeste    SP      248809  31769219.0  2351667.0  34120886.0  137.136864
# 17   Sudeste    MG      588384  13074245.0  3598852.0  16673097.0   28.337101
# 19   Sudeste    RJ       43910  12806488.0   599891.0  13406379.0  305.314940
# 16  Nordeste    BA      567295   7826843.0  4714902.0  12541745.0   22.107977
# 23       Sul    RS      282062   7581230.0  2056452.0   9637682.0   34.168665
# 21       Sul    PR      199709   7011990.0  1991814.0   9003804.0   45.084618
# 13  Nordeste  PE**       98938   5476915.0  1922216.0   7399131.0   74.785532
# 10  Nordeste    CE      146348   4713311.0  2096483.0   6809794.0   46.531514
# 4      Norte    PA     1253165   2949017.0  2561832.0   5510849.0    4.397545
# 7   Nordeste    MA      333366   2711557.0  2511008.0   5222565.0   15.666160
#
#     perc_rural  nao_sei_porque
# 20    0.068922        9.451696
# 17    0.215848        6.116502
# 19    0.044747       13.661831
# 16    0.375937        8.311200
# 23    0.213376        7.290780
# 21    0.221219        9.973582
# 13    0.259789       19.428491
# 10    0.307863       14.325327
# 4     0.464871        2.044289
# 7     0.480800        7.532286

# %%
# Quais estados com menos habitantes?
sorted_values.tail(10)
# Out:
#           regiao        uf  superficie  pop_urbana  pop_rural      total  \
# 24  Centro-Oeste        MS      358159   1604318.0   323516.0  1927834.0
# 27  Centro-Oeste        DF        5822   1692248.0   129698.0  1821946.0
# 15      Nordeste        SE       22050   1140569.0   483606.0  1624175.0
# 0          Norte        RO      238513    762864.0   468143.0  1231007.0
# 6          Norte        TO      278421    741009.0   307633.0  1048642.0
# 1          Norte        AC      153150    315401.0   168322.0   483726.0
# 5          Norte        AP      143454    330590.0    48869.0   379459.0
# 3          Norte        RR      225116    174277.0    72854.0   247131.0
# 9       Nordeste  Litígio*        2977         NaN        NaN        NaN
# 28           NaN  Ilhas***          10         NaN        NaN        NaN
#
#      densidade  perc_rural  nao_sei_porque
# 24    5.382621    0.167813        0.903275
# 27  312.941601    0.071187       22.277224
# 15   73.658730    0.297755       21.932245
# 0     5.161174    0.380293        1.962757
# 6     3.766390    0.293363        1.104920
# 1     3.158511    0.347970        1.099066
# 5     2.645162    0.128786        0.340660
# 3     1.097794    0.294799        0.323629
# 9          NaN         NaN             NaN
# 28         NaN         NaN             NaN
